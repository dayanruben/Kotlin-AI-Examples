// %%
%use kotlin-dl

val kinferenceVersion = "0.2.27"
val ktorVersion = "3.3.3"

USE {
    repositories {
        mavenCentral()
        maven("https://packages.jetbrains.team/maven/p/ki/maven")
        maven("https://packages.jetbrains.team/maven/p/grazi/grazie-platform-public")
    }
    dependencies {
        implementation("io.kinference:inference-core-jvm:$kinferenceVersion")
        implementation("io.kinference:inference-ort-jvm:$kinferenceVersion")
        implementation("io.kinference:serializer-protobuf-jvm:$kinferenceVersion")
        implementation("io.kinference:ndarray-core-jvm:$kinferenceVersion")

        implementation("io.ktor:ktor-client-core-jvm:$ktorVersion")
        implementation("io.ktor:ktor-client-cio-jvm:$ktorVersion")
    }
}

// %%
import io.kinference.ndarray.arrays.*
import io.kinference.ndarray.arrays.FloatNDArray.Companion.invoke
import io.kinference.ort.ORTEngine
import io.kinference.ort.data.tensor.ORTTensor
import io.kinference.utils.CommonDataLoader
import io.kinference.utils.inlines.InlineInt
import io.kinference.utils.toLongArray
import okio.Path.Companion.toPath
import org.jetbrains.kotlinx.dl.dataset.generator.FromFolders
import org.jetbrains.kotlinx.dl.impl.inference.imagerecognition.InputType
import java.awt.image.BufferedImage
import kotlin.collections.mutableMapOf
import io.kinference.core.KIONNXData
import io.kinference.core.data.tensor.KITensor
import io.kinference.ndarray.arrays.LongNDArray
import io.kinference.ndarray.arrays.NumberNDArrayCore
import io.ktor.client.HttpClient
import io.ktor.client.plugins.HttpTimeout
import io.ktor.client.request.prepareRequest
import io.ktor.client.statement.bodyAsChannel
import io.ktor.util.cio.writeChannel
import io.ktor.utils.io.copyAndClose
import java.io.File
import kotlinx.coroutines.runBlocking

// %%
/**
 * Directory used to store cached files.
 *
 * This variable combines the user's current working directory
 * with a "cache" subdirectory to create the path for storing cache files.
 * It is used in various functions to check for existing files or directories,
 * create new ones if they do not exist, and manage the caching of downloaded files.
 */
val cacheDirectory = System.getProperty("user.dir") + "/.cache/"


/**
 * Downloads a file from the given URL and saves it with the specified file name.
 *
 * Checks if the directory specified by `cacheDirectory` exists.
 * If not, it creates the directory. If the file already exists,
 * the download is skipped. Otherwise, the file is downloaded
 * using an HTTP client with a 10-minute timeout setting.
 *
 * @param url The URL from which to download the file.
 * @param fileName The name to use for the downloaded file.
 * @param timeout Optional timeout duration for the download request, in milliseconds.
 * Defaults to 600_000 milliseconds (10 minutes).
 * Increase the timeout if you are not sure that download for the particular model with fit into the default timeout.
 */
suspend fun downloadFile(url: String, fileName: String, timeout: Long = 600_000) {
    // Ensure the predefined path is treated as a directory
    val directory = File(cacheDirectory)

    // Check if the directory exists, if not create it
    if (!directory.exists()) {
        println("Predefined directory doesn't exist. Creating directory at $cacheDirectory.")
        directory.mkdirs() // Create the directory if it doesn't exist
    }

    // Check if the file already exists
    val file = File(directory, fileName)
    if (file.exists()) {
        println("File already exists at ${file.absolutePath}. Skipping download.")
        return // Exit the function if the file exists
    }

    // Create an instance of HttpClient with custom timeout settings
    val client = HttpClient {
        install(HttpTimeout) {
            requestTimeoutMillis = timeout
        }
    }

    // Download the file and write to the specified output path
    client.prepareRequest(url).execute { response ->
        response.bodyAsChannel().copyAndClose(file.writeChannel())
    }

    client.close()
}

// %%
// Constants for input and output tensor names used in the CaffeNet model
val INPUT_TENSOR_NAME = "data_0"
val OUTPUT_TENSOR_NAME = "prob_1"

// %%
// Preprocessing pipeline for input images using KotlinDL
val preprocessing = pipeline<BufferedImage>()
    .resize {
        outputWidth = 224
        outputHeight = 224
        interpolation = InterpolationType.BILINEAR
    }
    .convert { colorMode = ColorMode.BGR }
    .toFloatArray { }
    .call(InputType.CAFFE.preprocessing())

// Path to the small dataset of dogs vs cats images (100 images)
val dogsVsCatsDatasetPath = dogsCatsSmallDatasetPath()

// %%
/**
 * Creates a Map of input tensors categorized by their respective classes (e.g., "cat" and "dog").
 *
 * This function reads images from the dataset, preprocesses them,
 * transposes the tensors to the required format, and groups them
 * based on their class label.
 *
 * @return A Map where the keys are the class labels (e.g., "cat" and "dog"),
 * and the values are lists of KITensor objects representing the input tensors
 * for each class.
 */
suspend fun createInputs(): Map<String, List<ORTTensor>> {
    val dataset = OnFlyImageDataset.create(
        File(dogsVsCatsDatasetPath),
        FromFolders(mapping = mapOf("cat" to 0, "dog" to 1)),
        preprocessing
    ).shuffle()


    val tensorShape = intArrayOf(1, 224, 224, 3)        // Original tensor shape is [batch, width, height, channel]
    val permuteAxis = intArrayOf(0, 3, 1, 2)            // Permutations for shape [batch, channel, width, height]
    val inputTensors = mutableMapOf<String, MutableList<ORTTensor>>()

    for (i in 0 until dataset.xSize()) {
        val inputData = dataset.getX(i)
        val inputClass = if (dataset.getY(i).toInt() == 0) "cat" else "dog"
        val floatNDArray = FloatNDArray(tensorShape) { index: InlineInt -> inputData[index.value] }.transpose(permuteAxis)  // Create an NDArray from the image data
        val inputTensor = ORTTensor(floatNDArray.array.toArray(), floatNDArray.shape.toLongArray(), INPUT_TENSOR_NAME)      // Transpose and create a tensor from the NDArray
        inputTensors.putIfAbsent(inputClass, mutableListOf())
        inputTensors[inputClass]!!.add(inputTensor)
    }

    return inputTensors
}

// %%
/**
 * Displays the top 5 predictions with their corresponding labels and scores.
 *
 * @param predictions The predicted scores in a multidimensional array format.
 * @param classLabels The list of class labels corresponding to the predictions.
 * @param originalClass The actual class label of the instance being predicted.
 */
fun displayTopPredictions(predictions: ORTTensor, classLabels: List<String>, originalClass: String) {
    val predictionArray = predictions.toFloatArray()
    val indexedScores = predictionArray.withIndex().sortedByDescending { it.value }.take(5)

    println("\nOriginal class: $originalClass")
    println("Top 5 predictions:")
    for ((index, score) in indexedScores) {
        val predictedClassLabel = if (index in classLabels.indices) classLabels[index] else "Unknown"
        println("${predictedClassLabel}: ${"%.2f".format(score * 100)}%")
    }
}

// %%
val modelUrl = "https://github.com/onnx/models/raw/main/validated/vision/classification/caffenet/model/caffenet-12.onnx"
val synsetUrl = "https://s3.amazonaws.com/onnx-model-zoo/synset.txt"
val modelName = "CaffeNet"

// %%
runBlocking {
    println("Downloading model from: $modelUrl")
    downloadFile(modelUrl, "$modelName.onnx")
    println("Downloading synset from: $synsetUrl")
    downloadFile(synsetUrl, "synset.txt")

    val classLabels = File("$cacheDirectory/synset.txt").readLines()

    println("Loading model...")
    val model = ORTEngine.loadModel("$cacheDirectory/$modelName.onnx".toPath())
    println("Creating inputs...")
    val inputTensors = createInputs()

    println("Starting inference...")
    inputTensors.forEach { dataClass ->
        dataClass.value.forEach { tensor ->
            val actualOutputs = model.predict(listOf(tensor))
            val predictions = actualOutputs[OUTPUT_TENSOR_NAME]!! as ORTTensor
            displayTopPredictions(predictions, classLabels, dataClass.key)
        }
    }
}
// Out:
// Downloading model from: https://github.com/onnx/models/raw/main/validated/vision/classification/caffenet/model/caffenet-12.onnx
// File already exists at /Users/pavel.gorgulov/Projects/main_project/AI/Kotlin-AI-Examples/notebooks/kinference/.cache/CaffeNet.onnx. Skipping download.
// Downloading synset from: https://s3.amazonaws.com/onnx-model-zoo/synset.txt
// File already exists at /Users/pavel.gorgulov/Projects/main_project/AI/Kotlin-AI-Examples/notebooks/kinference/.cache/synset.txt. Skipping download.
// Loading model...
// Creating inputs...
// Starting inference...
//
// Original class: cat
// Top 5 predictions:
// n03825788 nipple: 12,60%
// n02097298 Scotch terrier, Scottish terrier, Scottie: 9,55%
// n02094433 Yorkshire terrier: 4,42%
// n03944341 pinwheel: 4,40%
// n07615774 ice lolly, lolly, lollipop, popsicle: 4,40%
//
// Original class: cat
// Top 5 predictions:
// n02124075 Egyptian cat: 42,12%
// n02123045 tabby, tabby cat: 29,15%
// n02123159 tiger cat: 17,08%
// n02127052 lynx, catamount: 4,28%
// n02123394 Persian cat: 3,40%
//
// Original class: cat
// Top 5 predictions:
// n02104365 schipperke: 9,79%
// n02107312 miniature pinscher: 9,33%
// n02105056 groenendael: 4,72%
// n02110627 affenpinscher, monkey pinscher, monkey dog: 4,03%
// n02108915 French bulldog: 3,96%
//
// Original class: cat
// Top 5 predictions:
// n02123394 Persian cat: 95,96%
// n02123045 tabby, tabby cat: 2,02%
// n02123159 tiger cat: 0,87%
// n02086240 Shih-Tzu: 0,18%
// n02086910 papillon: 0,18%
//
// Original class: cat
// Top 5 predictions:
// n02443114 polecat, fitch, foulmart, foumart, Mustela putorius: 22,63%
// n01873310 platypus, duckbill, duckbilled platypus, duck-billed platypus, Ornithorhynchus anatinus: 18,98%
// n02356798 fox squirrel, eastern fox squirrel, Sciurus niger: 11,07%
// n02441942 weasel: 10,78%
// n02509815 lesser panda, red panda, panda, bear cat, cat bear, Ailurus fulgens: 8,54%
//
// Original class: cat
// Top 5 predictions:
// n02124075 Egyptian cat: 33,81%
// n02123597 Siamese cat, Siamese: 32,13%
// n02127052 lynx, catamount: 8,46%
// n02123045 tabby, tabby cat: 5,89%
// n04553703 washbasin, handbasin, washbowl, lavabo, wash-hand basin: 4,71%
//
// Original class: cat
// Top 5 predictions:
// n02124075 Egyptian cat: 37,54%
// n02123045 tabby, tabby cat: 31,74%
// n02123159 tiger cat: 28,95%
// n02127052 lynx, catamount: 1,46%
// n02123394 Persian cat: 0,09%
//
// Original class: cat
// Top 5 predictions:
// n02124075 Egyptian cat: 46,10%
// n02123045 tabby, tabby cat: 36,38%
// n02123159 tiger cat: 15,85%
// n02127052 lynx, catamount: 1,42%
// n02125311 cougar, puma, catamount, mountain lion, painter, panther, Felis concolor: 0,07%
//
// Original class: cat
// Top 5 predictions:
// n04399382 teddy, teddy bear: 12,71%
// n02342885 hamster: 8,14%
// n03724870 mask: 7,30%
// n02655020 puffer, pufferfish, blowfish, globefish: 6,08%
// n01818515 macaw: 5,13%
//
// Original class: cat
// Top 5 predictions:
// n02124075 Egyptian cat: 31,53%
// n02123045 tabby, tabby cat: 17,05%
// n02123159 tiger cat: 8,13%
// n02127052 lynx, catamount: 7,82%
// n02123597 Siamese cat, Siamese: 7,05%
//
// Original class: cat
// Top 5 predictions:
// n02948072 candle, taper, wax light: 11,13%
// n02342885 hamster: 8,57%
// n04493381 tub, vat: 6,47%
// n02120079 Arctic fox, white fox, Alopex lagopus: 6,14%
// n02328150 Angora, Angora rabbit: 5,26%
//
// Original class: cat
// Top 5 predictions:
// n02123394 Persian cat: 50,95%
// n02342885 hamster: 15,36%
// n02104365 schipperke: 5,43%
// n02442845 mink: 5,11%
// n02112350 keeshond: 4,79%
//
// Original class: cat
// Top 5 predictions:
// n02123045 tabby, tabby cat: 68,75%
// n02123159 tiger cat: 17,15%
// n02124075 Egyptian cat: 14,00%
// n02127052 lynx, catamount: 0,07%
// n02971356 carton: 0,01%
//
// Original class: cat
// Top 5 predictions:
// n02123159 tiger cat: 16,50%
// n02085620 Chihuahua: 12,48%
// n02113023 Pembroke, Pembroke Welsh corgi: 9,89%
// n02112018 Pomeranian: 7,61%
// n02105855 Shetland sheepdog, Shetland sheep dog, Shetland: 6,52%
//
// Original class: cat
// Top 5 predictions:
// n02124075 Egyptian cat: 47,66%
// n02123045 tabby, tabby cat: 32,55%
// n02123159 tiger cat: 14,07%
// n02127052 lynx, catamount: 3,46%
// n04265275 space heater: 0,93%
//
// Original class: cat
// Top 5 predictions:
// n02123045 tabby, tabby cat: 33,85%
// n02124075 Egyptian cat: 28,17%
// n02127052 lynx, catamount: 20,78%
// n02123394 Persian cat: 7,81%
// n02123159 tiger cat: 7,72%
//
// Original class: cat
// Top 5 predictions:
// n02443114 polecat, fitch, foulmart, foumart, Mustela putorius: 29,87%
// n02123597 Siamese cat, Siamese: 26,00%
// n02441942 weasel: 11,64%
// n02443484 black-footed ferret, ferret, Mustela nigripes: 9,34%
// n02124075 Egyptian cat: 3,57%
//
// Original class: cat
// Top 5 predictions:
// n01514859 hen: 13,62%
// n02124075 Egyptian cat: 12,72%
// n02123045 tabby, tabby cat: 11,09%
// n01704323 triceratops: 6,24%
// n02123159 tiger cat: 4,47%
//
// Original class: cat
// Top 5 predictions:
// n02123159 tiger cat: 64,81%
// n02123045 tabby, tabby cat: 17,86%
// n02127052 lynx, catamount: 5,79%
// n02123394 Persian cat: 5,29%
// n02124075 Egyptian cat: 4,16%
//
// Original class: cat
// Top 5 predictions:
// n02123045 tabby, tabby cat: 77,07%
// n02123159 tiger cat: 11,52%
// n02124075 Egyptian cat: 7,80%
// n02971356 carton: 0,50%
// n03887697 paper towel: 0,31%
//
// Original class: cat
// Top 5 predictions:
// n02492035 capuchin, ringtail, Cebus capucinus: 48,79%
// n02125311 cougar, puma, catamount, mountain lion, painter, panther, Felis concolor: 20,10%
// n02119789 kit fox, Vulpes macrotis: 2,67%
// n02119022 red fox, Vulpes vulpes: 2,56%
// n02442845 mink: 2,26%
//
// Original class: cat
// Top 5 predictions:
// n02123045 tabby, tabby cat: 28,93%
// n02124075 Egyptian cat: 14,67%
// n02123159 tiger cat: 10,48%
// n02127052 lynx, catamount: 9,74%
// n02325366 wood rabbit, cottontail, cottontail rabbit: 6,35%
//
// Original class: cat
// Top 5 predictions:
// n02123045 tabby, tabby cat: 29,96%
// n02123159 tiger cat: 29,02%
// n02124075 Egyptian cat: 15,57%
// n02127052 lynx, catamount: 13,35%
// n02129604 tiger, Panthera tigris: 1,74%
//
// Original class: cat
// Top 5 predictions:
// n02106382 Bouvier des Flandres, Bouviers des Flandres: 19,01%
// n02090721 Irish wolfhound: 16,64%
// n02111277 Newfoundland, Newfoundland dog: 14,96%
// n02111129 Leonberg: 11,21%
// n02108551 Tibetan mastiff: 6,65%
//
// Original class: cat
// Top 5 predictions:
// n02124075 Egyptian cat: 40,29%
// n02123045 tabby, tabby cat: 32,39%
// n02123159 tiger cat: 13,81%
// n02123597 Siamese cat, Siamese: 5,14%
// n03793489 mouse, computer mouse: 2,98%
//
// Original class: cat
// Top 5 predictions:
// n02123159 tiger cat: 38,32%
// n02123045 tabby, tabby cat: 34,74%
// n02123394 Persian cat: 9,84%
// n02124075 Egyptian cat: 9,00%
// n02127052 lynx, catamount: 7,74%
//
// Original class: cat
// Top 5 predictions:
// n02124075 Egyptian cat: 74,99%
// n02123597 Siamese cat, Siamese: 8,17%
// n02123045 tabby, tabby cat: 7,37%
// n02123159 tiger cat: 1,04%
// n02109961 Eskimo dog, husky: 0,71%
//
// Original class: cat
// Top 5 predictions:
// n02123597 Siamese cat, Siamese: 92,10%
// n02328150 Angora, Angora rabbit: 4,67%
// n02127052 lynx, catamount: 1,99%
// n02123394 Persian cat: 0,61%
// n02124075 Egyptian cat: 0,21%
//
// Original class: cat
// Top 5 predictions:
// n02110627 affenpinscher, monkey pinscher, monkey dog: 27,30%
// n02097298 Scotch terrier, Scottish terrier, Scottie: 21,86%
// n02097047 miniature schnauzer: 18,38%
// n02093859 Kerry blue terrier: 14,50%
// n02106382 Bouvier des Flandres, Bouviers des Flandres: 3,21%
//
// Original class: cat
// Top 5 predictions:
// n02123597 Siamese cat, Siamese: 99,92%
// n03887697 paper towel: 0,01%
// n02112350 keeshond: 0,01%
// n02127052 lynx, catamount: 0,01%
// n04265275 space heater: 0,01%
//
// Original class: cat
// Top 5 predictions:
// n02123394 Persian cat: 59,49%
// n02123597 Siamese cat, Siamese: 10,85%
// n03325584 feather boa, boa: 5,50%
// n02123045 tabby, tabby cat: 4,68%
// n02123159 tiger cat: 2,79%
//
// Original class: cat
// Top 5 predictions:
// n02124075 Egyptian cat: 55,67%
// n02123045 tabby, tabby cat: 34,51%
// n02123159 tiger cat: 9,65%
// n02127052 lynx, catamount: 0,10%
// n02325366 wood rabbit, cottontail, cottontail rabbit: 0,02%
//
// Original class: cat
// Top 5 predictions:
// n02105056 groenendael: 50,96%
// n02104365 schipperke: 24,68%
// n02445715 skunk, polecat, wood pussy: 2,21%
// n02099267 flat-coated retriever: 2,19%
// n02106382 Bouvier des Flandres, Bouviers des Flandres: 1,48%
//
// Original class: cat
// Top 5 predictions:
// n02123045 tabby, tabby cat: 69,15%
// n02123159 tiger cat: 17,21%
// n02124075 Egyptian cat: 12,80%
// n02123394 Persian cat: 0,11%
// n02127052 lynx, catamount: 0,10%
//
// Original class: cat
// Top 5 predictions:
// n04235860 sleeping bag: 45,35%
// n02443484 black-footed ferret, ferret, Mustela nigripes: 4,77%
// n02342885 hamster: 3,51%
// n03825788 nipple: 2,47%
// n03814639 neck brace: 2,30%
//
// Original class: cat
// Top 5 predictions:
// n02124075 Egyptian cat: 78,11%
// n02123045 tabby, tabby cat: 15,53%
// n02123159 tiger cat: 5,91%
// n02127052 lynx, catamount: 0,36%
// n01883070 wombat: 0,05%
//
// Original class: cat
// Top 5 predictions:
// n02124075 Egyptian cat: 52,71%
// n02123045 tabby, tabby cat: 32,32%
// n02123159 tiger cat: 5,05%
// n02123597 Siamese cat, Siamese: 4,17%
// n02127052 lynx, catamount: 2,00%
//
// Original class: cat
// Top 5 predictions:
// n02124075 Egyptian cat: 70,32%
// n02127052 lynx, catamount: 17,60%
// n02123159 tiger cat: 6,90%
// n02123045 tabby, tabby cat: 3,53%
// n02128757 snow leopard, ounce, Panthera uncia: 0,84%
//
// Original class: cat
// Top 5 predictions:
// n02123597 Siamese cat, Siamese: 28,02%
// n01877812 wallaby, brush kangaroo: 22,79%
// n02098286 West Highland white terrier: 10,68%
// n02328150 Angora, Angora rabbit: 5,79%
// n02085620 Chihuahua: 4,33%
//
// Original class: cat
// Top 5 predictions:
// n02124075 Egyptian cat: 22,17%
// n02123045 tabby, tabby cat: 14,99%
// n02123597 Siamese cat, Siamese: 5,90%
// n03887697 paper towel: 5,32%
// n02123159 tiger cat: 4,61%
//
// Original class: cat
// Top 5 predictions:
// n03476991 hair spray: 9,00%
// n03729826 matchstick: 3,95%
// n03325584 feather boa, boa: 3,62%
// n01443537 goldfish, Carassius auratus: 3,59%
// n04456115 torch: 3,59%
//
// Original class: cat
// Top 5 predictions:
// n02328150 Angora, Angora rabbit: 20,84%
// n02364673 guinea pig, Cavia cobaya: 10,39%
// n02086910 papillon: 8,62%
// n02101388 Brittany spaniel: 7,56%
// n02086646 Blenheim spaniel: 4,62%
//
// Original class: cat
// Top 5 predictions:
// n02113186 Cardigan, Cardigan Welsh corgi: 28,37%
// n02123045 tabby, tabby cat: 14,76%
// n02124075 Egyptian cat: 6,84%
// n02105855 Shetland sheepdog, Shetland sheep dog, Shetland: 3,71%
// n02123597 Siamese cat, Siamese: 3,16%
//
// Original class: cat
// Top 5 predictions:
// n02100236 German short-haired pointer: 35,06%
// n02088632 bluetick: 12,47%
// n02095314 wire-haired fox terrier: 8,47%
// n02087046 toy terrier: 7,71%
// n02093647 Bedlington terrier: 5,28%
//
// Original class: cat
// Top 5 predictions:
// n02123045 tabby, tabby cat: 63,85%
// n02124075 Egyptian cat: 16,04%
// n02123159 tiger cat: 15,30%
// n02127052 lynx, catamount: 4,45%
// n01883070 wombat: 0,18%
//
// Original class: cat
// Top 5 predictions:
// n02123394 Persian cat: 80,13%
// n02123045 tabby, tabby cat: 9,62%
// n02124075 Egyptian cat: 4,23%
// n02123159 tiger cat: 3,29%
// n02112350 keeshond: 0,52%
//
// Original class: cat
// Top 5 predictions:
// n02123597 Siamese cat, Siamese: 25,15%
// n02096585 Boston bull, Boston terrier: 17,39%
// n02112706 Brabancon griffon: 10,57%
// n02113978 Mexican hairless: 6,20%
// n02087046 toy terrier: 6,04%
//
// Original class: cat
// Top 5 predictions:
// n02124075 Egyptian cat: 49,89%
// n02123045 tabby, tabby cat: 18,54%
// n02123159 tiger cat: 13,55%
// n02127052 lynx, catamount: 11,27%
// n02342885 hamster: 1,49%
//
// Original class: cat
// Top 5 predictions:
// n02127052 lynx, catamount: 91,21%
// n02123159 tiger cat: 1,97%
// n02115913 dhole, Cuon alpinus: 1,60%
// n02124075 Egyptian cat: 1,31%
// n02114855 coyote, prairie wolf, brush wolf, Canis latrans: 1,15%
//
// Original class: cat
// Top 5 predictions:
// n02096051 Airedale, Airedale terrier: 14,10%
// n02098105 soft-coated wheaten terrier: 11,96%
// n02095570 Lakeland terrier: 6,89%
// n02102318 cocker spaniel, English cocker spaniel, cocker: 5,89%
// n02091635 otterhound, otter hound: 5,37%
//
// Original class: dog
// Top 5 predictions:
// n02099712 Labrador retriever: 69,51%
// n02093428 American Staffordshire terrier, Staffordshire terrier, American pit bull terrier, pit bull terrier: